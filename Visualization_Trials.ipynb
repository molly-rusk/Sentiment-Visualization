# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.express as px
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("Airline-Sentiment-2-w-AA.csv", encoding= 'unicode_escape')
df
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      681448150    False   finalized                   3      2/25/15 5:24
# 1      681448153    False   finalized                   3      2/25/15 1:53
# 2      681448156    False   finalized                   3     2/25/15 10:01
# 3      681448158    False   finalized                   3      2/25/15 3:05
# 4      681448159    False   finalized                   3      2/25/15 5:50
# ...          ...      ...         ...                 ...               ...
# 14635  681679794    False   finalized                   3     2/25/15 19:46
# 14636  681679795    False   finalized                   3     2/25/15 19:14
# 14637  681679796    False   finalized                   3     2/25/15 19:04
# 14638  681679797    False   finalized                   3     2/25/15 18:59
# 14639  681679798    False   finalized                   3     2/25/15 19:06
#
# ...

# %%
shape = df.shape
shape
# Out:
# (14640, 20)

# %%
df.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'airline_sentiment',
#        'airline_sentiment:confidence', 'negativereason',
#        'negativereason:confidence', 'airline', 'airline_sentiment_gold',
#        'name', 'negativereason_gold', 'retweet_count', 'text', 'tweet_coord',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df['airline'].value_counts()
# Out:
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America     504
# Name: airline, dtype: int64

# %%
df['airline_sentiment'].value_counts()
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %%
# A histogram showing the number of neutral sentiment datapoints for all airlines in the dataset

# %%
df.groupby(['airline','airline_sentiment']).size()
# Out:
# airline         airline_sentiment
# American        negative             1960
#                 neutral               463
#                 positive              336
# Delta           negative              955
#                 neutral               723
#                 positive              544
# Southwest       negative             1186
#                 neutral               664
#                 positive              570
# US Airways      negative             2263
#                 neutral               381
#                 positive              269
# United          negative             2633
#                 neutral               697
#                 positive              492
# Virgin America  negative              181
#                 neutral               171
#                 positive              152
# dtype: int64

# %%
neutralamount = df[df['airline_sentiment'] == 'neutral'].groupby(['airline']).size()
neutralamount
# Out:
# airline
# American          463
# Delta             723
# Southwest         664
# US Airways        381
# United            697
# Virgin America    171
# dtype: int64

# %%
layout = go.Layout(title='Neutral sentiments per airline',
                  xaxis=dict(title='Senitments'),
                  yaxis=dict(title='Airline',
                            ))
fig = go.Figure([go.Bar(x=neutralamount)], layout=layout).show()
# Out:
# <div>                            <div id="1aacb003-b1a8-456d-8e6a-f7147757853d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1aacb003-b1a8-456d-8e6a-f7147757853d")) {                    Plotly.newPlot(                        "1aacb003-b1a8-456d-8e6a-f7147757853d",                        [{"x":[463,723,664,381,697,171],"type":"bar"}],                        {"title":{"text":"Neutral sentiments per airline"},"xaxis":{"title":{"text":"Senitments"}},"yaxis":{"title":{"text":"Airline"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0
# ...

# %%
# A histogram showing the count of each sentiment for the Delta airline
df.groupby(['airline','airline_sentiment']).size()
# Out:
# airline         airline_sentiment
# American        negative             1960
#                 neutral               463
#                 positive              336
# Delta           negative              955
#                 neutral               723
#                 positive              544
# Southwest       negative             1186
#                 neutral               664
#                 positive              570
# US Airways      negative             2263
#                 neutral               381
#                 positive              269
# United          negative             2633
#                 neutral               697
#                 positive              492
# Virgin America  negative              181
#                 neutral               171
#                 positive              152
# dtype: int64

# %%
deltasentiment = df[df['airline'] == 'Delta'].groupby(['airline_sentiment']).size()
deltasentiment
# Out:
# airline_sentiment
# negative    955
# neutral     723
# positive    544
# dtype: int64

# %%
layout2 = go.Layout(title='Sentiments for Delta', 
                  xaxis=dict(title='Amount'),
                  yaxis=dict(title='Sentiment Type'))
fig2 = go.Figure([go.Bar(x=deltasentiment)], layout=layout2).show()
# Out:
# <div>                            <div id="b38adcd0-cf87-4b4f-8717-429cc3e2762d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b38adcd0-cf87-4b4f-8717-429cc3e2762d")) {                    Plotly.newPlot(                        "b38adcd0-cf87-4b4f-8717-429cc3e2762d",                        [{"x":[955,723,544],"type":"bar"}],                        {"title":{"text":"Sentiments for Delta"},"xaxis":{"title":{"text":"Amount"}},"yaxis":{"title":{"text":"Sentiment Type"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fil
# ...

# %%
# A separate pie chart for each airline, showing the sentiment percentage for each sentiment
american = df[df['airline'] == 'American'].groupby(['airline_sentiment']).size()
american
# Out:
# airline_sentiment
# negative    1960
# neutral      463
# positive     336
# dtype: int64

# %%
fig3 = px.pie(df, values='airline_sentiment', names='airline')
fig3.show()
# Out:
# <div>                            <div id="97844a93-92f3-48e2-a99a-210a3bfac68b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97844a93-92f3-48e2-a99a-210a3bfac68b")) {                    Plotly.newPlot(                        "97844a93-92f3-48e2-a99a-210a3bfac68b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"airline=%{label}<br>airline_sentiment=%{value}<extra></extra>","labels":["Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin America","Virgin Americ
# ...

# %%
# Additonal visualization 
golden = df['_golden'].value_counts()
golden
# Out:
# False    14600
# True        40
# Name: _golden, dtype: int64

# %%
layout3 = go.Layout(title='Golden amounts', 
                  xaxis=dict(title='Amount'),
                  yaxis=dict(title='Golden'))
fig4 = go.Figure([go.Bar(x=golden)], layout=layout3).show()
# Out:
# <div>                            <div id="9da2ef9b-196d-49c7-9e0b-1f0e0172ba42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9da2ef9b-196d-49c7-9e0b-1f0e0172ba42")) {                    Plotly.newPlot(                        "9da2ef9b-196d-49c7-9e0b-1f0e0172ba42",                        [{"x":[14600,40],"type":"bar"}],                        {"title":{"text":"Golden amounts"},"xaxis":{"title":{"text":"Amount"}},"yaxis":{"title":{"text":"Golden"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay",
# ...

# %% [markdown]
# **Which airlines are doing a good job capturing customer satisfaction?**

# %%
df.groupby(['airline','airline_sentiment']).size()
# Out:
# airline         airline_sentiment
# American        negative             1960
#                 neutral               463
#                 positive              336
# Delta           negative              955
#                 neutral               723
#                 positive              544
# Southwest       negative             1186
#                 neutral               664
#                 positive              570
# US Airways      negative             2263
#                 neutral               381
#                 positive              269
# United          negative             2633
#                 neutral               697
#                 positive              492
# Virgin America  negative              181
#                 neutral               171
#                 positive              152
# dtype: int64

# %% [markdown]
# **Based on the data, all of the airlines have more negative sentiments than positive. Virgin American has the smallest ratio of negative to positive sentiments.**

# %% [markdown]
# **How should American airlines strategically differentiate themselves in the coming year? What opportunities do they have?**

# %%
df[df['airline'] == 'American'].groupby(['negativereason']).size()
# Out:
# negativereason
# Bad Flight                      87
# Can't Tell                     198
# Cancelled Flight               246
# Customer Service Issue         768
# Damaged Luggage                 12
# Flight Attendant Complaints     87
# Flight Booking Problems        130
# Late Flight                    249
# Lost Luggage                   149
# longlines                       34
# dtype: int64

# %% [markdown]
# **American Airlines has one of the highest negative to positive sentiment ratios. The largest negative reason was customer service issues. American Airlines needs to improve how they handle their customer service issues to improve in the coming year.**

# %%
df2 = pd.read_csv("Twitter-sentiment-self-drive-DFE.csv", encoding='unicode_escape')
df2
# Out:
#        _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     724227031     True      golden                 236               NaN
# 1     724227032     True      golden                 231               NaN
# 2     724227033     True      golden                 233               NaN
# 3     724227034     True      golden                 240               NaN
# 4     724227035     True      golden                 240               NaN
# ...         ...      ...         ...                 ...               ...
# 7151  726942339     True      golden                  65               NaN
# 7152  726942340     True      golden                  71               NaN
# 7153  726942341     True      golden                  63               NaN
# 7154  726942342     True      golden                  67               NaN
# 7155  726942343     True      golden                  83               NaN
#
#          sentiment  sentiment:confidence  our_id sentiment_gold  \
# ...

# %%
shape2 = df2.shape
shape2
# Out:
# (7156, 11)

# %%
df2.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'sentiment', 'sentiment:confidence', 'our_id',
#        'sentiment_gold', 'sentiment_gold_reason', 'text'],
#       dtype='object')

# %%
# Scatter plot showing sentiment on the x-axis, with the y-axis indicating the level of confidence on the sentiment
df2['sentiment'].value_counts()
# Out:
# 3               4245
# 4               1444
# 2                685
# 5                459
# not_relevant     213
# 1                110
# Name: sentiment, dtype: int64

# %%
df2['sentiment:confidence'].value_counts()
# Out:
# 1.0000    2705
# 0.7561      41
# 0.7604      36
# 0.7513      29
# 0.7500      28
#           ...
# 0.3571       1
# 0.5209       1
# 0.2510       1
# 0.3687       1
# 0.8431       1
# Name: sentiment:confidence, Length: 1564, dtype: int64

# %%
df2.groupby(['sentiment', 'sentiment:confidence']).size(
)
# Out:
# sentiment     sentiment:confidence
# 1             0.3630                   1
#               0.3679                   1
#               0.3716                   1
#               0.3729                   1
#               0.3774                   1
#                                       ..
# not_relevant  0.8854                   1
#               0.8861                   1
#               0.8866                   1
#               0.9607                   1
#               1.0000                  35
# Length: 2684, dtype: int64

# %%
sentiments = df2['sentiment']
confidence = df2['sentiment:confidence']
fig5 = go.Figure([go.Scatter(x=sentiments,
                             y=confidence)]).show()
# Out:
# <div>                            <div id="14bd95c7-d7b3-4bda-9ccc-fbb73a5bffc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14bd95c7-d7b3-4bda-9ccc-fbb73a5bffc8")) {                    Plotly.newPlot(                        "14bd95c7-d7b3-4bda-9ccc-fbb73a5bffc8",                        [{"x":["5","5","2","2","3","3","not_relevant","not_relevant","5","1","3","3","3","4","4","3","3","3","3","3","3","3","3","3","3","3","3","3","3","3","not_relevant","3","3","3","5","3","3","3","3","3","3","3","not_relevant","3","3","3","3","3","3","5","3","3","3","3","3","3","3","3","3","3","3","3","4","4","2","3","5","2","5","3","3","3","3","3","3","3","3","3","3","3","3","4","3","3","3","3","3","3","3","3","5","3","4","3","1","3","3","5","4","3","3","4","3","3","
# ...

# %%
# Scatter plot indicating the length of response (in characters) on the y axis and the confidence level on the x axis
lengthofres = df2['text']
confidence2 = df2['sentiment:confidence']
fig6 = go.Figure([go.Scatter(x=lengthofres,
                            y=confidence2)]).show()
# Out:
# <div>                            <div id="c9fcbb95-2922-4b7a-b438-545b4858ab30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9fcbb95-2922-4b7a-b438-545b4858ab30")) {                    Plotly.newPlot(                        "c9fcbb95-2922-4b7a-b438-545b4858ab30",                        [{"x":["Two places I'd invest all my money if I could: 3D printing and Self-driving cars!!!","Awesome! Google driverless cars will help the blind travel more often; https://t.co/QWuXR0FrBpv","If Google maps can't keep up with road construction, how am I supposed to trust a driverless car to get around here?","Autonomous cars seem way overhyped given the technology challenges; pilotless planes seem much more doable and needed.","Just saw Google self-driving car on 
# ...

# %%
# Pie chart showing a summary of all sentiments, but only sentiment judgements with a confidence of higher than 0.8
sentconf = df2['sentiment:confidence'] > 0.8
sentconf
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 7151    False
# 7152    False
# 7153     True
# 7154     True
# 7155     True
# Name: sentiment:confidence, Length: 7156, dtype: bool

# %%
fig7 = go.Figure([go.Pie(labels=sentiment:confidence,
                        values=sentconf)]).show()
# Out:
#   Input In [124]
#     fig7 = go.Figure([go.Pie(labels=sentiment:confidence,
#                                              ^
# SyntaxError: invalid syntax

# %%
# Your choice. Pie chart showing percent of golden vs. finalized unit states
unitstate = df2['_unit_state']
sents = df2['sentiment']
fig8 = go.Figure([go.Pie(labels=unitstate,
                        values=sents)]).show()
# Out:
# <div>                            <div id="288cd148-4a8b-4bb7-95d8-a93cfa4c8576" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("288cd148-4a8b-4bb7-95d8-a93cfa4c8576")) {                    Plotly.newPlot(                        "288cd148-4a8b-4bb7-95d8-a93cfa4c8576",                        [{"labels":["golden","golden","golden","golden","golden","golden","golden","golden","golden","golden","golden","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalized","finalize
# ...

# %%
df2['text'].value_counts()
# Out:
# Just saw the google car!                                                                  5
# Just saw the google car                                                                   4
# I SAW THE GOOGLE CAR                                                                      2
# How is an automated vehicle supposed to behave in an emergency? #AutoAuto                 2
# Just saw the Google car!                                                                  2
#                                                                                          ..
# Jammin' Spic Girls with Mr. Google Car man http://t.co/nyitx8Fiz0                         1
# Jammin' to Spice Girls with the google Car #SprangBrake http://t.co/VuWBfBL3YK            1
# I am going to look for Google car so Bud, my dog, can be on Google Maps.                  1
# Google car in Pittsboro. Large contraption on top. Must be doing street level mapping.    1
# ...

# %% [markdown]
# **Research questions:**
#
#  1. What are some of the primary concerns about self-driving cars, based on this dataset?
#  One of the main concerns is how a self-driving car would behave in an emergency.

# %% [markdown]
# 2. What is the public sentiment for self driving cars?

# %%
df2['sentiment'].value_counts()
# Out:
# 3               4245
# 4               1444
# 2                685
# 5                459
# not_relevant     213
# 1                110
# Name: sentiment, dtype: int64

# %% [markdown]
# Based on the sentiment results, assuming 5 is the highest sentiment confidence and 1 is the lowest, most people have average or below average confidence in self-driving cars.
